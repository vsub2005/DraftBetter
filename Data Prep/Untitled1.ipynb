# %%
import pandas as pd

# %%
pd.read_csv("/Users/vinaysubramanian/Downloads/PolygenceProject/data_v2/yearly/2019.csv")
# Out:
#      Unnamed: 0               Player   Tm Pos   Age     G    GS    Cmp    Att  \
# 0             0  Christian McCaffrey  CAR  RB  23.0  16.0  16.0    0.0    2.0
# 1             1        Lamar Jackson  BAL  QB  22.0  15.0  15.0  265.0  401.0
# 2             2        Derrick Henry  TEN  RB  25.0  15.0  15.0    0.0    0.0
# 3             3          Aaron Jones  GNB  RB  25.0  16.0  16.0    0.0    0.0
# 4             4      Ezekiel Elliott  DAL  RB  24.0  16.0  16.0    0.0    0.0
# ..          ...                  ...  ...  ..   ...   ...   ...    ...    ...
# 615         615      Ray-Ray McCloud  CAR   0  23.0   6.0   0.0    0.0    0.0
# 616         616     Darrius Shepherd  GNB  WR  24.0   6.0   0.0    0.0    0.0
# 617         617      Jarrett Stidham  NWE  QB  23.0   3.0   0.0    2.0    4.0
# 618         618       Michael Walker  JAX  WR  23.0   7.0   0.0    0.0    0.0
# 619         619        Corey Clement  PHI   0  25.0   4.0   0.0    0.0    0.0
#
# ...

# %%
x = pd.read_csv("/Users/vinaysubramanian/Downloads/PolygenceProject/data_v2/yearly/2019.csv")

# %%
x.describe()
# Out:
#        Unnamed: 0         Age           G          GS        Cmp         Att  \
# count  620.000000  620.000000  620.000000  620.000000  620.00000  620.000000
# mean   309.500000   26.008065   10.566129    4.953226   18.26129   28.772581
# std    179.122863    3.406010    5.255090    5.408610   70.31567  110.033237
# min      0.000000   21.000000    1.000000    0.000000    0.00000    0.000000
# 25%    154.750000   24.000000    6.000000    0.000000    0.00000    0.000000
# 50%    309.500000   25.000000   12.000000    3.000000    0.00000    0.000000
# 75%    464.250000   27.000000   16.000000    9.000000    0.00000    0.000000
# max    619.000000   42.000000   17.000000   16.000000  408.00000  626.000000
#
#                Yds         Int       Att.1        Yds.1  ...  FumblesLost  \
# count   620.000000  620.000000  620.000000   620.000000  ...   620.000000
# mean    207.772581    0.658065   21.572581    93.114516  ...     0.467742
# ...

# %%
qb = x[x.Pos == 'QB']

# %%
qb.describe()
# Out:
#        Unnamed: 0        Age          G         GS         Cmp         Att  \
# count   71.000000  71.000000  71.000000  71.000000   71.000000   71.000000
# mean   239.647887  28.507042   8.633803   7.281690  159.183099  250.788732
# std    192.809388   5.168236   5.705234   6.372223  144.822582  224.947417
# min      1.000000  22.000000   1.000000   0.000000    0.000000    0.000000
# 25%     83.500000  24.000000   3.000000   1.000000   25.000000   44.500000
# 50%    154.000000  27.000000   8.000000   5.000000  100.000000  160.000000
# 75%    385.000000  31.000000  15.000000  15.000000  309.000000  480.000000
# max    617.000000  42.000000  16.000000  16.000000  408.000000  626.000000
#
#                Yds        Int       Att.1        Yds.1  ...  FumblesLost  \
# count    71.000000  71.000000   71.000000    71.000000  ...    71.000000
# mean   1809.309859   5.704225   25.704225   108.422535  ...     1.859155
# ...

# %%
wr = x[x.Pos == 'WR']
wr.describe()
# Out:
#        Unnamed: 0         Age           G          GS         Cmp         Att  \
# count  217.000000  217.000000  217.000000  217.000000  217.000000  217.000000
# mean   278.921659   25.631336   11.391705    5.562212    0.055300    0.096774
# std    157.043808    2.745794    4.701115    5.350411    0.248481    0.353342
# min      6.000000   21.000000    1.000000    0.000000    0.000000    0.000000
# 25%    145.000000   24.000000    8.000000    1.000000    0.000000    0.000000
# 50%    276.000000   25.000000   13.000000    4.000000    0.000000    0.000000
# 75%    412.000000   27.000000   16.000000   10.000000    0.000000    0.000000
# max    618.000000   36.000000   17.000000   16.000000    2.000000    2.000000
#
#               Yds         Int       Att.1       Yds.1  ...  FumblesLost  \
# count  217.000000  217.000000  217.000000  217.000000  ...   217.000000
# mean     1.225806    0.009217    1.479263    9.990783  ...     0.271889
# ...

# %%
rb = x[x.Pos == 'RB']
rb.describe()
# Out:
#        Unnamed: 0        Age           G          GS         Cmp         Att  \
# count  153.000000  153.00000  153.000000  153.000000  153.000000  153.000000
# mean   272.006536   25.30719   11.718954    3.915033    0.052288    0.078431
# std    166.553354    2.86375    4.682635    5.164336    0.358925    0.466361
# min      0.000000   21.00000    1.000000    0.000000    0.000000    0.000000
# 25%    125.000000   23.00000    9.000000    0.000000    0.000000    0.000000
# 50%    257.000000   25.00000   13.000000    1.000000    0.000000    0.000000
# 75%    416.000000   27.00000   16.000000    7.000000    0.000000    0.000000
# max    589.000000   36.00000   16.000000   16.000000    4.000000    5.000000
#
#               Yds         Int       Att.1        Yds.1  ...  FumblesLost  \
# count  153.000000  153.000000  153.000000   153.000000  ...   153.000000
# mean     0.601307    0.006536   73.235294   311.830065  ...     0.522876
# ...

# %%
te = x[x.Pos == 'TE']
te.describe()
# Out:
#        Unnamed: 0         Age           G          GS    Cmp    Att    Yds  \
# count  116.000000  116.000000  116.000000  116.000000  116.0  116.0  116.0
# mean   319.086207   26.413793   11.784483    6.060345    0.0    0.0    0.0
# std    146.996218    3.413704    4.399221    4.874581    0.0    0.0    0.0
# min      7.000000   21.000000    1.000000    0.000000    0.0    0.0    0.0
# 25%    213.500000   24.000000    8.000000    2.000000    0.0    0.0    0.0
# 50%    341.000000   26.000000   13.000000    5.000000    0.0    0.0    0.0
# 75%    423.000000   28.000000   16.000000   10.000000    0.0    0.0    0.0
# max    602.000000   39.000000   16.000000   16.000000    0.0    0.0    0.0
#
#          Int       Att.1       Yds.1  ...  FumblesLost  PassingYds  PassingTD  \
# count  116.0  116.000000  116.000000  ...   116.000000       116.0      116.0
# mean     0.0    0.206897    1.336207  ...     0.129310         0.0        0.0
# ...

# %%
qbMean = qb.loc[:, 'FantasyPoints'].astype(int).mean()
qb[qb.loc[:, 'FantasyPoints'].astype(int)>qbMean]
# Out:
#     Unnamed: 0             Player   Tm Pos   Age     G    GS    Cmp    Att  \
# 1            1      Lamar Jackson  BAL  QB  22.0  15.0  15.0  265.0  401.0
# 11          11       Dak Prescott  DAL  QB  26.0  16.0  16.0  388.0  596.0
# 13          13     Russell Wilson  SEA  QB  31.0  16.0  16.0  341.0  516.0
# 16          16     Deshaun Watson  HOU  QB  24.0  15.0  15.0  333.0  495.0
# 29          29     Jameis Winston  TAM  QB  25.0  16.0  16.0  380.0  626.0
# 43          43         Josh Allen  BUF  QB  23.0  16.0  16.0  271.0  461.0
# 47          47    Patrick Mahomes  KAN  QB  24.0  14.0  14.0  319.0  484.0
# 49          49       Kyler Murray  ARI  QB  22.0  16.0  16.0  349.0  542.0
# 55          55      Aaron Rodgers  GNB  QB  36.0  16.0  16.0  353.0  569.0
# 59          59       Carson Wentz  PHI  QB  27.0  16.0  16.0  388.0  607.0
# 68          68          Matt Ryan  ATL  QB  34.0  15.0  15.0  408.0  616.0
# ...

# %%
teMean = te.loc[:, 'FantasyPoints'].astype(int).mean()
te[te.loc[:, 'FantasyPoints'].astype(int)>teMean]
# Out:
#      Unnamed: 0             Player   Tm Pos   Age     G    GS  Cmp  Att  Yds  \
# 7             7       Travis Kelce  KAN  TE  30.0  16.0  16.0  0.0  0.0  0.0
# 12           12       Mark Andrews  BAL  TE  23.0  15.0   4.0  0.0  0.0  0.0
# 15           15      George Kittle  SFO  TE  26.0  14.0  14.0  0.0  0.0  0.0
# 18           18      Darren Waller  OAK  TE  27.0  16.0  16.0  0.0  0.0  0.0
# 21           21          Zach Ertz  PHI  TE  29.0  15.0  15.0  0.0  0.0  0.0
# 24           24         Jared Cook  NOR  TE  32.0  14.0   7.0  0.0  0.0  0.0
# 30           30      Austin Hooper  ATL  TE  25.0  13.0  10.0  0.0  0.0  0.0
# 53           53       Hunter Henry  LAC  TE  25.0  12.0  12.0  0.0  0.0  0.0
# 56           56       Tyler Higbee  LAR  TE  26.0  15.0  15.0  0.0  0.0  0.0
# 61           61     Dallas Goedert  PHI  TE  24.0  15.0   9.0  0.0  0.0  0.0
# 63           63       Mike Gesicki  MIA  TE  24.0  16.0   5.0  0.0  0.0  0.0
# ...

# %%
wrMean = wr.loc[:, 'FantasyPoints'].astype(int).mean()
wr[wr.loc[:, 'FantasyPoints'].astype(int)>wrMean]
# Out:
#      Unnamed: 0            Player   Tm Pos   Age     G    GS  Cmp  Att   Yds  \
# 6             6    Michael Thomas  NOR  WR  26.0  16.0  15.0  0.0  0.0   0.0
# 14           14      Chris Godwin  TAM  WR  23.0  14.0  14.0  0.0  0.0   0.0
# 19           19    Kenny Golladay  DET  WR  26.0  16.0  16.0  0.0  0.0   0.0
# 25           25       Cooper Kupp  LAR  WR  26.0  16.0  14.0  0.0  1.0   0.0
# 26           26       Julio Jones  ATL  WR  30.0  15.0  15.0  0.0  0.0   0.0
# ..          ...               ...  ...  ..   ...   ...   ...  ...  ...   ...
# 211         211       Allen Hurns  MIA  WR  28.0  14.0   7.0  0.0  0.0   0.0
# 216         216      Russell Gage  ATL  WR  23.0  16.0   4.0  0.0  0.0   0.0
# 219         219    Adam Humphries  TEN  WR  26.0  12.0   3.0  0.0  0.0   0.0
# 222         222  Demaryius Thomas  NYJ  WR  32.0  11.0  10.0  0.0  0.0   0.0
# 231         231     Albert Wilson  MIA  WR  27.0  13.0   4.0  1.0  2.0  20.0
#
# ...

# %%
rbMean = rb.loc[:, 'FantasyPoints'].astype(int).mean()
rb[rb.loc[:, 'FantasyPoints'].astype(int)>rbMean]
# Out:
#      Unnamed: 0               Player   Tm Pos   Age     G    GS  Cmp  Att  \
# 0             0  Christian McCaffrey  CAR  RB  23.0  16.0  16.0  0.0  2.0
# 2             2        Derrick Henry  TEN  RB  25.0  15.0  15.0  0.0  0.0
# 3             3          Aaron Jones  GNB  RB  25.0  16.0  16.0  0.0  0.0
# 4             4      Ezekiel Elliott  DAL  RB  24.0  16.0  16.0  0.0  0.0
# 5             5          Dalvin Cook  MIN  RB  24.0  14.0  14.0  0.0  0.0
# 8             8           Nick Chubb  CLE  RB  24.0  16.0  16.0  0.0  0.0
# 9             9        Austin Ekeler  LAC  RB  24.0  16.0   8.0  0.0  0.0
# 10           10          Mark Ingram  BAL  RB  30.0  15.0  15.0  0.0  0.0
# 17           17         Chris Carson  SEA  RB  25.0  15.0  15.0  0.0  0.0
# 20           20       Saquon Barkley  NYG  RB  22.0  13.0  13.0  0.0  0.0
# 22           22            Joe Mixon  CIN  RB  23.0  16.0  15.0  0.0  0.0
# 23           23          Todd Gurley  LAR  RB  25.0  15.0  15.0  0.0  0.0
# ...
